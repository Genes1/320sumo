# %% [markdown]
# # This file is used to scrape for wrestler data.

# %%
import sys
# !{sys.executable} -m pip install lxml 
# !{sys.executable} -m pip install html5lib
# Out:
# Requirement already satisfied: lxml in /opt/conda/lib/python3.8/site-packages (4.6.3)
# Requirement already satisfied: html5lib in /opt/conda/lib/python3.8/site-packages (1.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.8/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.8/site-packages (from html5lib) (1.15.0)

# %%
import matplotlib as mpltlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime


import requests, re, json
from bs4 import BeautifulSoup
import math

import rank_helper
import kimarite_helper

# %%
def get_df_by_id(id):
    
    URL = f"http://sumodb.sumogames.de/Rikishi.aspx?r={id}"
    basepage = requests.get(URL)
    soup = BeautifulSoup(basepage.content, 'html.parser')
    
    try:
        highest = soup.find('table', class_='rikishidata')
        highest = highest.find('table', class_='rikishidata')#.find('tr').findAll('td')[1].contents[0]
        highest = highest.find('tr').findAll('td')[1].contents[0]
        highest = str(highest.split()[0]).replace('-', '')
    except:
        print(f"{id} skipped prelim")
        return
    
    
    if not rank_helper.rank_is_top(highest, True):
        print(f"{id} rejected")
        return 


    get_data = soup.find_all('tr')


    # texts that we have to convert, since it's an image in the table
    txt1 = '<img border="0" src="img/hoshi_shiro.gif"/>'     # win, white circle
    txt2 = '<img border="0" src="img/hoshi_yasumi.gif"/>'    # withdrawal, dash
    txt3 = '<img border="0" src="img/hoshi_kuro.gif"/>'      # loss, black circle
    txt4 = '<img border="0" src="img/hoshi_fusenpai.gif"/>'  # ff, black square
    txt5 = '<img border="0" src="img/hoshi_fusensho.gif"/>' #hoshi_fusensho # withdrawal, white square


    # convert the images to W(win) F(forfeit) L(loss)
    edited = str(get_data).replace(txt1, 'W')
    edited = edited.replace(txt2, 'F')
    edited = edited.replace(txt3, 'L')
    edited = edited.replace(txt4, 'A') # absence 
    edited = edited.replace(txt5, 'W') # enemy ff counts as win


    # put the record table into a dataframe
    test = pd.read_html(edited)
    df = test[2]

    # rename columns
    df.columns = ['Date','Rank', 'Series','W_L','Yusho_standing', 'Height/weight']
    #df['Series'] = df['Series'].replace(np.nan,"")
    # if there is no series, there is no relevant data here most likely (record too old, maezumo)
    df.dropna(subset = ["Series"], inplace=True)

    # drop any possible name banner columns
    df = df[df.W_L.apply(lambda x: '-' in x)]

    # convert dates to string, then datetime

    #df[:, 'Date'] = df["Date"].astype(str)
    df['Date'] = pd.to_datetime(df['Date'].astype(str), format='%Y.%m')

    # we don't really care about yusho standing and height/weight. drop them
    # df['Yusho_standing'] = df['Yusho_standing'].replace(np.nan,"")
    df = df.drop(columns=['Yusho_standing', 'Height/weight'])



    # calculate streaks
    # divide games into 5 sections, if any of the sectios contains W, then
    #series = df['Series'].values

    forfeit_list = []
    win_list = []
    lose_list = []
    ab_list = []
    streak_list = []

    for index, row in df.iterrows():
        f_count = 0
        w_count = 0
        l_count = 0
        a_count = 0
        row_series = row['Series']


        # get W/L/F/A by counting
        for s in row_series:
            if(s == 'F'):
                f_count += 1 
            if(s == 'W'):
                w_count += 1
            if(s == 'L'):
                l_count += 1
            if(s == 'A'):
                a_count += 1

        forfeit_list.append(f_count)
        win_list.append(w_count)
        lose_list.append(l_count)
        ab_list.append(a_count)

        # game is a streak when you win 4 or more games in a row
        streak_list.append(sum(1 for x in re.finditer(r'W{4,}', row['Series'])))






    # make new columns
    df['Win'] = win_list
    df['Loss'] = lose_list
    df['Forfeit'] = forfeit_list
    df['Absence'] = ab_list



    # calculate win rate: (W/# games played), ignoring the games forfeited
    df['Winrate'] = (df['Win']/(15 - (df['Forfeit'] + df['Absence'])))*100
    # remove nans
    df['Winrate'] = df['Winrate'].replace(np.nan,0)
    # round the numbers to the 2 decimal place
    df['Winrate'] = df['Winrate'].round(2)


    # change streak column to Y or N
    # might be a good move to limit the winrate here as well?
    change = []
    for s in streak_list:
        if(s > 0):
            change.append('Y')
        else:
            change.append('N')


    df['Streak(Wins)'] = change
    df.insert(0, 'id', id)
        

    

    # only get the top division tournaments
    return df

# %%
df = get_df_by_id(2933)#.append(get_df_by_id(1), ignore_index=True) 
df.shape
# Out:
# (0, 11)

# %%
x = df.loc[df['Streak(Wins)'] == 'Y']
x.head()

mean_wr = x['Winrate'].mean()
mean_wr

# average win rate is 65.91%



test_mean = df['Streak(Wins)'].value_counts().Y
test_mean

# 53 tournaments are streaky



streaky_games = test_mean / len(df)
streaky_games

# 50.48% of the tournaments are streaky, which is good
# but we might have to consider analyzing amount of forfeit/absence numbers, 
# as it could be an interaction term for thrusters vs streakiness
# Out:
# 0.6103896103896104

# %% [markdown]
# <br>
#
# # DO NOT RUN THIS UNLESS YOU ARE SCRAPING!

# %%
# up to 12670
# 2933 empty test case

# for problematic pages
e = []

# go through 0, 13 for everyone
for batch in range(12, 13):
    
    aggregate_df = pd.DataFrame()
    
    for i in range(1 + 1000 * batch, 1000 * (batch+1)):
        print(f"Processing {i}...")
        next = None
        try:
            next = get_df_by_id(i)
        except:
            e.append(i)
        aggregate_df = aggregate_df.append(next, ignore_index=True)

        #df = df[df.Rank.apply(lambda x: rank_helper.rank_is_top(x))]
    
    aggregate_df.to_csv(f'tournaments_all_{batch}.csv', index = False)
# Out:
# Processing 12001...
# 12001 rejected
# Processing 12002...
# 12002 rejected
# Processing 12003...
# 12003 rejected
# Processing 12004...
# 12004 rejected
# Processing 12005...
# 12005 rejected
# Processing 12006...
# 12006 rejected
# Processing 12007...
# 12007 rejected
# Processing 12008...
# 12008 rejected
# Processing 12009...
# 12009 rejected
# Processing 12010...
# 12010 rejected
# Processing 12011...
# 12011 rejected
# Processing 12012...
# 12012 rejected
# Processing 12013...
# 12013 rejected
# Processing 12014...
# 12014 rejected
# Processing 12015...
# <ipython-input-4-0f60cf1706ca>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'].astype(str), format='%Y.%m')
# Processing 12016...
# 12016 rejected
# Processing 12017...
# 12017 rejected
# Processing 12018...
# 12018 rejected
# Processing 12019...
# 12019 rejected
# Processing 12020...
# 12020 rejected
# Processing 12021...
# 12021 rejected
# Processing 12022...
# 12022 rejected
# Processing 12023...
# 12023 rejected
# Processing 12024...
# <ipython-input-4-0f60cf1706ca>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'].astype(str), format='%Y.%m')
# Processing 12025...
# 12025 rejected
# Processing 12026...
# <ipython-input-4-0f60cf1706ca>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'].astype(str), format='%Y.%m')
# Processing 
# 12728 skipped prelim
# Processing 12729...
# 12729 skipped prelim
# Processing 12730...
# 12730 skipped prelim
# Processing 12731...
# 12731 skipped prelim
# Processing 12732...
# 12732 skipped prelim
# Processing 12733...
# 12733 skipped prelim
# Processing 12734...
# 12734 skipped prelim
# Processing 12735...
# 12735 skipped prelim
# Processing 12736...
# 12736 skipped prelim
# Processing 12737...
# 12737 skipped prelim
# Processing 12738...
# 12738 skipped prelim
# Processing 12739...
# 12739 skipped prelim
# Processing 12740...
# 12740 skipped prelim
# Processing 12741...
# 12741 skipped prelim
# Processing 12742...
# 12742 skipped prelim
# Processing 12743...
# 12743 skipped prelim
# Processing 12744...
# 12744 skipped prelim
# Processing 12745...
# 12745 skipped prelim
# Processing 12746...
# 12746 skipped prelim
# Processing 12747...
# 12747 skipped prelim
# Processing 12748...
# 12748 skipped prelim
# Processing 12749...
# 12749 skipped prelim
# Processing 12750...
# 12750 skipped prelim
# Processing 12751...
# 12751 skipped prelim
# Processing 12752...
# 12752 skipped prelim
# Processing 12753...
# 12753 skipped prelim
# Processing 12754...
# 12754 skipped prelim
# Processing 12755...
# 12755 skipped prelim
# Processing 12756...
# 12756 skipped prelim
# Processing 12757...
# 12757 skipped prelim
# Processing 12758...
# 12758 skipped prelim
# Processing 12759...
# 12759 skipped prelim
# Processing 12760...
# 12760 skipped prelim
# Processing 12761...
# 12761 skipped prelim
# Processing 12762...
# 12762 skipped prelim
# Processing 12763...
# 12763 skipped prelim
# Processing 12764...
# 12764 skipped prelim
# Processing 12765...
# 12765 skipped prelim
# Processing 12766...
# 12766 skipped prelim
# Processing 12767...
# 12767 skipped prelim
# Processing 12768...
# 12768 skipped prelim
# Processing 12769...
# 12769 skipped prelim
# Processing 12770...
# 12770 skipped prelim
# Processing 12771...
# 12771 skipped prelim
# Processing 12772...
# 12772 skipped prelim
# Processing 12773...
# 12773 skipped prelim
# Processing 12774...
# 12774 skipped prelim
# Processing 12775...
# 12775 skipped prelim
# Processing 12776...
# 12776 skipped prelim
# Processing 12777...
# 12777 skipped prelim
# Processing 12778...
# 12778 skipped prelim
# Processing 12779...
# 12779 skipped prelim
# Processing 12780...
# 12780 skipped prelim
# Processing 12781...
# 12781 skipped prelim
# Processing 12782...
# 12782 skipped prelim
# Processing 12783...
# 12783 skipped prelim
# Processing 12784...
# 12784 skipped prelim
# Processing 12785...
# 12785 skipped prelim
# Processing 12786...
# 12786 skipped prelim
# Processing 12787...
# 12787 skipped prelim
# Processing 12788...
# 12788 skipped prelim
# Processing 12789...
# 12789 skipped prelim
# Processing 12790...
# 12790 skipped prelim
# Processing 12791...
# 12791 skipped prelim
# Processing 12792...
# 12792 skipped prelim
# Processing 12793...
# 12793 skipped prelim
# Processing 12794...
# 12794 skipped prelim
# Processing 12795...
# 12795 skipped prelim
# Processing 12796...
# 12796 skipped prelim
# Processing 12797...
# 12797 skipped prelim
# Processing 12798...
# 12798 skipped prelim
# Processing 12799...
# 12799 skipped prelim
# Processing 12800...
# 12800 skipped prelim
# Processing 12801...
# 12801 skipped prelim
# Processing 12802...
# 12802 skipped prelim
# Processing 12803...
# 12803 skipped prelim
# Processing 12804...
# 12804 skipped prelim
# Processing 12805...
# 12805 skipped prelim
# Processing 12806...
# 12806 skipped prelim
# Processing 12807...
# 12807 skipped prelim
# Processing 12808...
# 12808 skipped prelim
# Processing 12809...
# 12809 skipped prelim
# Processing 12810...
# 12810 skipped prelim
# Processing 12811...
# 12811 skipped prelim
# Processing 12812...
# 12812 skipped prelim
# Processing 12813...
# 12813 skipped prelim
# Processing 12814...
# 12814 skipped prelim
# Processing 12815...
# 12815 skipped prelim
# Processing 12816...
# 12816 skipped prelim
# Processing 12817...
# 12817 skipped prelim
# Processing 12818...
# 12818 skipped prelim
# Processing 12819...
# 12819 skipped prelim
# Processing 12820...
# 12820 skipped prelim
# Processing 12821...
# 12821 skipped prelim
# Processing 12822...
# 12822 skipped prelim
# Processing 12823...
# 12823 skipped prelim
# Processing 12824...
# 12824 skipped prelim
# Processing 12825...
# 12825 skipped prelim
# Processing 12826...
# 12826 skipped prelim
# Processing 12827...
# 12827 skipped prelim
# Processing 12828...
# 12828 skipped prelim
# Processing 12829...
# 12829 skipped prelim
# Processing 12830...
# 12830 skipped prelim
# Processing 12831...
# 12831 skipped prelim
# Processing 12832...
# 12832 skipped prelim
# Processing 12833...
# 12833 skipped prelim
# Processing 12834...
# 12834 skipped prelim
# Processing 12835...
# 12835 skipped prelim
# Processing 12836...
# 12836 skipped prelim
# Processing 12837...
# 12837 skipped prelim
# Processing 12838...
# 12838 skipped prelim
# Processing 12839...
# 12839 skipped prelim
# Processing 12840...
# 12840 skipped prelim
# Processing 12841...
# 12841 skipped prelim
# Processing 12842...
# 12842 skipped prelim
# Processing 12843...
# 12843 skipped prelim
# Processing 12844...
# 12844 skipped prelim
# Processing 12845...
# 12845 skipped prelim
# Processing 12846...
# 12846 skipped prelim
# Processing 12847...
# 12847 skipped prelim
# Processing 12848...
# 12848 skipped prelim
# Processing 12849...
# 12849 skipped prelim
# Processing 12850...
# 12850 skipped prelim
# Processing 12851...
# 12851 skipped prelim
# Processing 12852...
# 12852 skipped prelim
# Processing 12853...
# 12853 skipped prelim
# Processing 12854...
# 12854 skipped prelim
# Processing 12855...
# 12855 skipped prelim
# Processing 12856...
# 12856 skipped prelim
# Processing 12857...
# 12857 skipped prelim
# Processing 12858...
# 12858 skipped prelim
# Processing 12859...
# 12859 skipped prelim
# Processing 12860...
# 12860 skipped prelim
# Processing 12861...
# 12861 skipped prelim
# Processing 12862...
# 12862 skipped prelim
# Processing 12863...
# 12863 skipped prelim
# Processing 12864...
# 12864 skipped prelim
# Processing 12865...
# 12865 skipped prelim
# Processing 12866...
# 12866 skipped prelim
# Processing 12867...
# 12867 skipped prelim
# Processing 12868...
# 12868 skipped prelim
# Processing 12869...
# 12869 skipped prelim
# Processing 12870...
# 12870 skipped prelim
# Processing 12871...
# 12871 skipped prelim
# Processing 12872...
# 12872 skipped prelim
# Processing 12873...
# 12873 skipped prelim
# Processing 12874...
# 12874 skipped prelim
# Processing 12875...
# 12875 skipped prelim
# Processing 12876...
# 12876 skipped prelim
# Processing 12877...
# 12877 skipped prelim
# Processing 12878...
# 12878 skipped prelim
# Processing 12879...
# 12879 skipped prelim
# Processing 12880...
# 12880 skipped prelim
# Processing 12881...
# 12881 skipped prelim
# Processing 12882...
# 12882 skipped prelim
# Processing 12883...
# 12883 skipped prelim
# Processing 12884...
# 12884 skipped prelim
# Processing 12885...
# 12885 skipped prelim
# Processing 12886...
# 12886 skipped prelim
# Processing 12887...
# 12887 skipped prelim
# Processing 12888...
# 12888 skipped prelim
# Processing 12889...
# 12889 skipped prelim
# Processing 12890...
# 12890 skipped prelim
# Processing 12891...
# 12891 skipped prelim
# Processing 12892...
# 12892 skipped prelim
# Processing 12893...
# 12893 skipped prelim
# Processing 12894...
# 12894 skipped prelim
# Processing 12895...
# 12895 skipped prelim
# Processing 12896...
# 12896 skipped prelim
# Processing 12897...
# 12897 skipped prelim
# Processing 12898...
# 12898 skipped prelim
# Processing 12899...
# 12899 skipped prelim
# Processing 12900...
# 12900 skipped prelim
# Processing 12901...
# 12901 skipped prelim
# Processing 12902...
# 12902 skipped prelim
# Processing 12903...
# 12903 skipped prelim
# Processing 12904...
# 12904 skipped prelim
# Processing 12905...
# 12905 skipped prelim
# Processing 12906...
# 12906 skipped prelim
# Processing 12907...
# 12907 skipped prelim
# Processing 12908...
# 12908 skipped prelim
# Processing 12909...
# 12909 skipped prelim
# Processing 12910...
# 12910 skipped prelim
# Processing 12911...
# 12911 skipped prelim
# Processing 12912...
# 12912 skipped prelim
# Processing 12913...
# 12913 skipped prelim
# Processing 12914...
# 12914 skipped prelim
# Processing 12915...
# 12915 skipped prelim
# Processing 12916...
# 12916 skipped prelim
# Processing 12917...
# 12917 skipped prelim
# Processing 12918...
# 12918 skipped prelim
# Processing 12919...
# 12919 skipped prelim
# Processing 12920...
# 12920 skipped prelim
# Processing 12921...
# 12921 skipped prelim
# Processing 12922...
# 12922 skipped prelim
# Processing 12923...
# 12923 skipped prelim
# Processing 12924...
# 12924 skipped prelim
# Processing 12925...
# 12925 skipped prelim
# Processing 12926...
# 12926 skipped prelim
# Processing 12927...
# 12927 skipped prelim
# Processing 12928...
# 12928 skipped prelim
# Processing 12929...
# 12929 skipped prelim
# Processing 12930...
# 12930 skipped prelim
# Processing 12931...
# 12931 skipped prelim
# Processing 12932...
# 12932 skipped prelim
# Processing 12933...
# 12933 skipped prelim
# Processing 12934...
# 12934 skipped prelim
# Processing 12935...
# 12935 skipped prelim
# Processing 12936...
# 12936 skipped prelim
# Processing 12937...
# 12937 skipped prelim
# Processing 12938...
# 12938 skipped prelim
# Processing 12939...
# 12939 skipped prelim
# Processing 12940...
# 12940 skipped prelim
# Processing 12941...
# 12941 skipped prelim
# Processing 12942...
# 12942 skipped prelim
# Processing 12943...
# 12943 skipped prelim
# Processing 12944...
# 12944 skipped prelim
# Processing 12945...
# 12945 skipped prelim
# Processing 12946...
# 12946 skipped prelim
# Processing 12947...
# 12947 skipped prelim
# Processing 12948...
# 12948 skipped prelim
# Processing 12949...
# 12949 skipped prelim
# Processing 12950...
# 12950 skipped prelim
# Processing 12951...
# 12951 skipped prelim
# Processing 12952...
# 12952 skipped prelim
# Processing 12953...
# 12953 skipped prelim
# Processing 12954...
# 12954 skipped prelim
# Processing 12955...
# 12955 skipped prelim
# Processing 12956...
# 12956 skipped prelim
# Processing 12957...
# 12957 skipped prelim
# Processing 12958...
# 12958 skipped prelim
# Processing 12959...
# 12959 skipped prelim
# Processing 12960...
# 12960 skipped prelim
# Processing 12961...
# 12961 skipped prelim
# Processing 12962...
# 12962 skipped prelim
# Processing 12963...
# 12963 skipped prelim
# Processing 12964...
# 12964 skipped prelim
# Processing 12965...
# 12965 skipped prelim
# Processing 12966...
# 12966 skipped prelim
# Processing 12967...
# 12967 skipped prelim
# Processing 12968...
# 12968 skipped prelim
# Processing 12969...
# 12969 skipped prelim
# Processing 12970...
# 12970 skipped prelim
# Processing 12971...
# 12971 skipped prelim
# Processing 12972...
# 12972 skipped prelim
# Processing 12973...
# 12973 skipped prelim
# Processing 12974...
# 12974 skipped prelim
# Processing 12975...
# 12975 skipped prelim
# Processing 12976...
# 12976 skipped prelim
# Processing 12977...
# 12977 skipped prelim
# Processing 12978...
# 12978 skipped prelim
# Processing 12979...
# 12979 skipped prelim
# Processing 12980...
# 12980 skipped prelim
# Processing 12981...
# 12981 skipped prelim
# Processing 12982...
# 12982 skipped prelim
# Processing 12983...
# 12983 skipped prelim
# Processing 12984...
# 12984 skipped prelim
# Processing 12985...
# 12985 skipped prelim
# Processing 12986...
# 12986 skipped prelim
# Processing 12987...
# 12987 skipped prelim
# Processing 12988...
# 12988 skipped prelim
# Processing 12989...
# 12989 skipped prelim
# Processing 12990...
# 12990 skipped prelim
# Processing 12991...
# 12991 skipped prelim
# Processing 12992...
# 12992 skipped prelim
# Processing 12993...
# 12993 skipped prelim
# Processing 12994...
# 12994 skipped prelim
# Processing 12995...
# 12995 skipped prelim
# Processing 12996...
# 12996 skipped prelim
# Processing 12997...
# 12997 skipped prelim
# Processing 12998...
# 12998 skipped prelim
# Processing 12999...
# 12999 skipped prelim

# %%
aggregate_df
# Out:
#          id       Date   Rank           Series    W_L  Win  Loss  Forfeit  \
# 0     12015 2012-05-01   Jk8e  FWLFFLLFWFWFWFF    4-3    4     3        8
# 1     12015 2012-07-01  Jd76e  WFFWFWWFFLWFFWF    6-1    6     1        8
# 2     12015 2012-09-01   Jd5w  FLFWFWFWLFWFFLF    4-3    4     3        8
# 3     12015 2012-11-01  Sd86w  FFFFFFFFFFFFFFF  0-0-7    0     0       15
# 4     12015 2013-01-01  Jd47e  LFWFFWWFLFFWFWF    5-2    5     2        8
# ...     ...        ...    ...              ...    ...  ...   ...      ...
# 1586  12575 2020-07-01  Ms10w  WFLFFWFWWFWFFFW    6-1    6     1        8
# 1587  12575 2020-09-01   Ms2w  FFFFFFFFFFFFFFF  0-0-7    0     0       15
# 1588  12575 2020-11-01   Ms2w  FLWFWFWFLFLFWFF    4-3    4     3        8
# 1589  12575 2021-01-01   J14w  LWWLLWWLLWWLWWL    8-7    8     7        0
# 1590  12575 2021-03-01   J11e  LWLLLLLLLWWWWWW    7-8    7     8        0
#
#       Absence  Winrate Streak(Wins)
# 0           0    57.14            N
# 1           0    85.71            N
# 2           0    57.14            N
# 3           0     0.00            N
# 4           0    71.43            N
# ...       ...      ...          ...
# 1586        0    85.71            N
# 1587        0     0.00            N
# 1588        0    57.14            N
# 1589        0    53.33            N
# 1590        0    46.67            Y
#
# [1591 rows x 11 columns]

# %%
# if scraping occured, merge all files
aggregate_df = pd.DataFrame()
for i in range(0, 13):
    if i != 10: # there is nothing in this file.
        df = pd.read_csv(f'tournaments_all_{i}.csv')
        aggregate_df = aggregate_df.append(df)
        
#aggregate_df = aggregate_df.groupby('id').filter(lambda x : len(x) > 5)
aggregate_df.to_csv(f'tournaments_all.csv', index = False)

aggregate_df.shape
# Out:
# (67350, 11)

# %%
df1 = pd.read_csv(f'tournaments_all.csv')
df2 = pd.read_csv(f'tournaments_all_copy.csv')

df = df1.append(df2)
df = df.drop_duplicates()
df.to_csv(f'tournaments_all_final.csv', index = False)

# %% [markdown]
# ***

# %%
# load the saved tournament df
df = pd.read_csv(f'tournaments_all_final.csv')
print(df.shape)


# example of selecting only the top two divisions
df = df[df.Rank.apply(lambda x: rank_helper.rank_is_top(x))]
print(df.shape)
# Out:
# (67351, 11)
# (34995, 11)

# %%
# get the push score (m), push win% (p), and number of wins (n) of a given wrestler by their ID.
def get_m_by_id(id):
    
    kimarite_URL = f"http://sumodb.sumogames.de/Rikishi_kim.aspx?r={id}"
    print(f"processing {id}...")
    basepage = requests.get(kimarite_URL)
    soup = BeautifulSoup(basepage.content, 'html.parser')

    # get winning data table 
    kimarite_wins = soup.find('table', class_="ro_left")

    # this gets all winning moves in like [<tr><td class="rb_kim">oshidashi</td><td class="right"><a href="#0oshidashi">143</a></td></tr>, ...]
    cells = kimarite_wins.find_all('tr')

    kimarite_labels, kimarite_amts = [], []

    for cell in cells:
        win_name_tag, win_amt_tag = cell.find_all('td')
        kimarite_labels.append(win_name_tag.text.strip())
        kimarite_amts.append(int(win_amt_tag.text.strip()))


    # at this point we have all kimarite. reduce it so that only moves with >= 5% significance are displayed
    up_to_index = 0
    total_wins = sum(kimarite_amts)
    for i in range(0, len(kimarite_amts)):
        amt = kimarite_amts[i]
        # we find the most significant kimarite under 10%
        if amt / total_wins < 0.05:
            up_to_index = i
            break

    # we now slice off everything up to and past this point, label it as 'other'
    kimarite_labels = kimarite_labels[:up_to_index] + ["other"]
    kimarite_amts = kimarite_amts[:up_to_index] + [sum(kimarite_amts[up_to_index:])]

    #print(kimarite_labels)
    #print(kimarite_amts)

    #print((shikona, kimarite_amts, kimarite_labels))
    
    
    n = sum(kimarite_amts)
    if n == 0:
        return (None, None, None)
